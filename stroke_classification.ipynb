# %% [markdown]
# ## Introduction
# This notebook consists of two parts:
# 1- Classifying Stroke Disease using predictive modeling
# 2- Report

# %% [markdown]
# ## 1- Classifying Stroke Disease using predictive modeling
# The problem of classifying stroke disease will be studied. Python scikit-learn machine learning package is used and 3 different classification models will be tested:
# 1- Logistic Regression
# 2- Decision Tree
# 3- Random Forest

# %% [markdown]
# ### Functions
# The following functions were created to read, discover, splitting into training/testing sets, modeling and predicting data, and visualizing results.

# %%
# importing required packages
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams.update({'font.size': 14})
import itertools

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.multiclass import unique_labels
from imblearn.over_sampling import RandomOverSampler
import warnings
warnings.filterwarnings("ignore")

# 1
def importing_data(path):
    ''' importing data '''
    df = pd.read_csv(path)
    return df

# # 2
# def discovering_data(df):
#     ''' discovering data '''
#     print(62 * '=')
#     print('data head\n', df.head(), '\n')
#     print(62 * '=')
#     #print('data tail\n', df.tail(), '\n')
#     #print(62 * '=')
#     print('data description\n', df.groupby('stroke').describe(), '\n')
#     print(62 * '=')

# 3
def modified_data(df, smoker = False):
    ''' modified data '''
    df_ = df.copy()
    df_['bmi'] = df_['bmi'].fillna(df_['bmi'].mean())
    if smoker:
        df_['smoking_status'].fillna(df_['smoking_status'].mode()[0], inplace = True)
    else:
        df_.drop('smoking_status', axis = 1, inplace = True)
        
    return df_

# 4
def trn_tst_split(df, test_size = 0.2, random_state = 2019):
    '''splitting data into training and testing sets '''
    df_ = df.copy()
    X, y = df_.loc[:,~df_.columns.isin(['id', 'stroke'])], df_['stroke']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size, random_state = random_state)
    return X_train, X_test, y_train, y_test

# 5
def label_encoding(df):
    ''' Auto encodes any dataframe column of type category or object '''
    cat_features = list(df.select_dtypes(include=['category','object']))
    le = LabelEncoder()
    for feature in cat_features:
        try:
            df[feature] = le.fit_transform(df[feature])
        except:
            print('Error encoding '+feature)
    return df

# 6
def classifiers(class_weight = None):
    ''' defining the models that will be used in classification, class_weight = None or 'balanced' '''
    rs = 2019
    clsf = []
    clsf.append(('LR', LogisticRegression(class_weight = class_weight, random_state = rs)))
    clsf.append(('DT', DecisionTreeClassifier(class_weight = class_weight, random_state = rs)))
    clsf.append(('RF', RandomForestClassifier(class_weight = class_weight, random_state = rs)))
    #clsf.append(('SVC', SVC(kernel='sigmoid', class_weight = class_weight, random_state = rs)))
    #clsf.append(('GB', GradientBoostingClassifier()))
    #clsf.append(('KNN', KNeighborsClassifier()))
    #clsf.append(('GNB', GaussianNB()))
    return dict(clsf)

# 7
def train_classifier(clsf, X_train, y_train): 
    '''training a classifier to fit a trained set'''
    model = clsf.fit(X_train, y_train)
    return model 

# 8
def predict_labels(model, X_test):
    '''using the classifier to predict labels of test set'''
    y_pred = model.predict(X_test)
    return y_pred  

# 9
def accuracy_confusion(clsf, X_train, y_train, X_test, y_test):
    ''' getting accuracy for each model and predicted labels and the confusion matrix '''
    clsf_key = []
    scores = []
    #df_pred = []
    target_names = ['0', '1']  
    for key, value in clsf.items():
        model = train_classifier(value, X_train, y_train)     # training classifier by using the training set
        y_pred = predict_labels(model, X_test)     # testing the classifier by using test set
        #print(X_test.shape, y_pred.shape, y_test.shape)
        cnf_matrix = confusion_matrix(y_test, y_pred)    # getting the confusion matrix
        print(' Model: ' + key, '\n', classification_report(y_test, y_pred, target_names = target_names), '\n')
        clsf_key.append(key)
        scores.append(accuracy_score(y_test, y_pred))  # calculating Accuracy of each model        
        print('\n', 'Accuracy of the ' + '"' + key + '"' + ' model = ', round(accuracy_score(y_test, y_pred) * 100, 2), '%', '\n' )
        plot_confusion_matrix(key, y_test, y_pred, target_names, True)   
        print(60 * '=')
    df_scores = pd.DataFrame({'Classifier': clsf_key, 'Score': scores})
    return df_scores.sort_values(by = 'Score', ascending = False).reset_index(drop = True)

# 10
def random_over_sampling(X_train, y_train):
    ''' performing random over sampling to convert imbalanced data into balanced '''
    ros = RandomOverSampler(random_state = 2019)
    X_ros, y_ros = ros.fit_resample(X_train, y_train)
    print('ros shape for features) :   {}'.format(X_ros.shape))
    print('ros shape for labels) :   {}'.format(y_ros.shape))
    return X_ros, y_ros

# 11
def plot_confusion_matrix(k, y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes  #[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print('normalized confusion matrix of the ' + '"' + k + '"' + ' model ' )
    else:
        print('confusion matrix of the ' + '"' + k + '"' + ' model ')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    plt.show()

#%%

# %%
#print module versions for reproducibility
import matplotlib
import imblearn
print('Numby version {}'.format(np.__version__))
print('Pandas version {}'.format(pd.__version__))
print('Matplotlib version {}'.format(matplotlib.__version__))
print('PandasProfiling version {}'.format(pandas_profiling.__version__))
print('Sklearn version {}'.format(sklearn.__version__))
print('Imblearn version {}'.format(imblearn.__version__))
# Out:
# Numby version 1.16.5
# Pandas version 0.25.1
# Matplotlib version 3.1.1
# PandasProfiling version 2.3.0
# Sklearn version 0.21.3
# Imblearn version 0.5.0

# %%
path = r'D:\tech_test\train_2v.csv'     # Stroke data path
df = importing_data(path)               # importing data as a pandas dataframe

# %% [markdown]
# ### Exploring the data
# Instead of using Pandas package to explore the data, I will use **Pandas Profiling** package which is a great package that could be used to analyze the data and to get an overview about variables, data types, missing values and visualizing the data. In only one line of code you will have the data analyzed, please see the **full_report** below:

# %%
full_report = pandas_profiling.ProfileReport(df)   # data exploring full report

# %%
full_report
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %% [markdown]
# The main aim of this work is to predict the stroke disease, ['stroke'] label, by using all or some of the features above, i.e, ['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi'].
# From the **full_report** I noticed three important things:
# - 3.4% of df.bmi column is missing. To deal with this issue, the missing values will be filled with the mean value of df.bmi
# - 30.6% of df.smoking_status is missing. We have two scenarios for this case:
#     * I will remove the 'smoking_status' column and a new dataset that does not contain it will be created and will be called df_without_smoking_status
#     * I will fill the missing data with mode() and the new dataset is called df_with_smoking_status
# - The data is imbalanced because 98.2% of patients do not have stroke disease. So, the problem that we are going to solve need to be handled carefully before using machine learning to build the predictive model. Three different approaches will be introduced:
#     * ignoring class weight, i.e, using imbalanced data as it is (class_weight = None)
#     * setting class_weight = 'balance', where the class weights for unbalanced classes of the dataset will be estimated
#     * the random oversampling method from **imblearn** package will be used to convert imbalanced data into balanced one
# Details are given below:

# %% [markdown]
# ### Modifying the dataset
# Here, the **modified_data(df, smoker = False)** is used to remove the **smoking_status** column and then the categorical columns are encoded by using the function **label_encoding**. Then the new data frame is called **df_without_smoking_status**.
# The same method is used to create **df_with_smoking_status** dataset where the missing values of the **smoking_status** column are filled with the mode.

# %%
df_without_smoking_status = label_encoding(modified_data(df, smoker = False))   # removing smoking_status colomn
df_with_smoking_status = label_encoding(modified_data(df, smoker = True))   # fill missing data of smoking_status colomn with mode()

# %%
#df_without_smoking_status.columns  #print columns of the modified dataset that does not have smoking_status

# %%
#df_with_smoking_status.columns  #print columns of the modified dataset that has smoking_status

# %% [markdown]
# ### Train_test split the dataset
# The function **trn_tst_split** is used to split the modified datasets (**df_without_smoking_status, df_with_smoking_status**) into train (80%) and test (20%) samples:

# %%
X_train_wo, X_test_wo, y_train_wo, y_test_wo = trn_tst_split(df_without_smoking_status) # traim_test_split without smoking_status
X_train_w, X_test_w, y_train_w, y_test_w = trn_tst_split(df_with_smoking_status)     # traim_test_split with smoking_status

# %%
#X_train_wo.head()

# %%
print(' Shape of training featurs without (wo) smoking_status column', X_train_wo.shape)
print(' Shape of training label without (wo) smoking_status column', y_train_wo.shape)
print(' Shape of test sample without (wo) smoking_status column', X_test_wo.shape)
print(' Shape of test label without (wo) smoking_status column', y_test_wo.shape)
# Out:
#  Shape of training featurs without (wo) smoking_status column (34720, 9)
#  Shape of training label without (wo) smoking_status column (34720,)
#  Shape of test sample without (wo) smoking_status column (8680, 9)
#  Shape of test label without (wo) smoking_status column (8680,)

# %% [markdown]
# ### Classifiers
# We are going to use these classification models through this work:

# %%
clsf_none = classifiers(class_weight = None)   # using 'classifiers' function with imbalanced dataset
clsf_balanced = classifiers(class_weight = 'balanced')  # using 'classifiers' function to create a balanced dataset

# %%
print("The used classifiers are: ", [k for k in clsf_none.keys()])
# Out:
# The used classifiers are:  ['LR', 'DT', 'RF']

# %% [markdown]
# ### Predictive models
# The classifiers (**clsf_none**) are used to train classification models on the train set then the model will be used to validate the data by using the test set. Accuracies of the models and confusion matrix are extracted and visualized. The **accuracy_confusion** function is used to do all of that:

# %% [markdown]
# ## 2 - Report
# I will give some comments on the results obtained and its discussion:

# %% [markdown]
# ### A- Imbalanced Data:

# %%
df_scores_wo_none = accuracy_confusion(clsf_none, X_train_wo, y_train_wo, X_test_wo, y_test_wo) # imbalanced data without smoking_status
# Out:
#  Model: LR
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8522
#            1       0.00      0.00      0.00       158
#
#     accuracy                           0.98      8680
#    macro avg       0.49      0.50      0.50      8680
# weighted avg       0.96      0.98      0.97      8680
#
#
#
#  Accuracy of the "LR" model =  98.18 %
#
# normalized confusion matrix of the "LR" model
# [[1. 0.]
#  [1. 0.]]
# ...
#  Model: DT
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8522
#            1       0.05      0.06      0.05       158
#
#     accuracy                           0.96      8680
#    macro avg       0.51      0.52      0.52      8680
# weighted avg       0.97      0.96      0.96      8680
#
#
#
#  Accuracy of the "DT" model =  95.96 %
#
# normalized confusion matrix of the "DT" model
# [[0.9761793  0.0238207 ]
#  [0.93670886 0.06329114]]
# ...
#  Model: RF
# ...

# %%
df_scores_wo_none  # print the accuracy of each classifier
# Out:
#   Classifier     Score
# 0         LR  0.981797
# 1         RF  0.981336
# 2         DT  0.959562

# %% [markdown]
# ### Comments on results (Imbalanced data)
# Among the 3 classifiers used, the Linear Regression Classifier (LR) has the highest accuracy (98.18%) of predicting stroke disease, then the Random Forest Classifier (RF) with approximately (98.13%). The  Decision Tree (DT) has prediction accuracy of (95.96%). General conclusion, even if the accuracies are high, but the models could not predict probably Class [1], i.e, could not predict if a patient has a stroke disease and the models predictions are biased towards Class [0]. For that, classifying the imbalanced data is not suitable for classifying the stroke dataset.

# %% [markdown]
# ### B- Balanced Data (class_weight = 'balanced')

# %%
df_scores_wo_balanced = accuracy_confusion(clsf_balanced, X_train_wo, y_train_wo, X_test_wo, y_test_wo) # using class_weight = 'balanced' without smoking_status
# Out:
#  Model: LR
#                precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85      8522
#            1       0.05      0.81      0.10       158
#
#     accuracy                           0.74      8680
#    macro avg       0.52      0.77      0.48      8680
# weighted avg       0.98      0.74      0.83      8680
#
#
#
#  Accuracy of the "LR" model =  74.04 %
#
# normalized confusion matrix of the "LR" model
# [[0.73914574 0.26085426]
#  [0.18987342 0.81012658]]
# ...
#  Model: DT
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8522
#            1       0.05      0.05      0.05       158
#
#     accuracy                           0.97      8680
#    macro avg       0.52      0.52      0.52      8680
# weighted avg       0.97      0.97      0.97      8680
#
#
#
#  Accuracy of the "DT" model =  96.52 %
#
# normalized confusion matrix of the "DT" model
# [[0.98216381 0.01783619]
# ...

# %%
df_scores_wo_balanced # print the accuracy of each classifier class_weight = 'balanced'
# Out:
#   Classifier     Score
# 0         RF  0.981336
# 1         DT  0.965207
# 2         LR  0.740438

# %% [markdown]
#
# ### Comments on results (class_weight = 'balanced')
# Among the 3 classifiers used, the Random Forest Classifier (RF) has the highest accuracy (98.13%) of predicting stroke disease, then the Decision Tree (DT) with approximately (96.52%). The Linear Regression Classifier (LR) has prediction accuracy of (74.04%). General conclusion, better improvement specially with the LR model even it has not a high accuracy but it could detect both classes of stroke disease. The other models could not predict the stroke classes probably, so that classifying using class_weight = 'balanced' does not work well for our data.

# %% [markdown]
# ### C- Random Oversampling method
# Now' I will use the **random_over_sampling** function to create balanced dataset:

# %%
X_ros_train_wo, y_ros_train_wo = random_over_sampling(X_train_wo, y_train_wo) #without smoking_status column
# Out:
# ros shape for features) :   (68190, 9)
# ros shape for labels) :   (68190,)

# %%
X_ros_train_w, y_ros_train_w = random_over_sampling(X_train_w, y_train_w)  #with smoking_status column
# Out:
# ros shape for features) :   (68190, 10)
# ros shape for labels) :   (68190,)

# %%
print('ros no of rows per class is balanced: ', np.bincount(y_ros_train_wo))
# Out:
# ros no of rows per class is balanced:  [34095 34095]

# %%
# print(X_test_wo.shape, y_test_wo.shape) 
# print(y_test_wo.value_counts())

# %% [markdown]
# Then, split the balanced data into train and test samples

# %% [markdown]
# Then, the accuracy and confusion matrix are obtained by using **randon oversampling** method

# %%
df_scores_ros_wo_none = accuracy_confusion(clsf_none, X_ros_train_wo, y_ros_train_wo, X_test_wo, y_test_wo) #without smoking_status column
# Out:
#  Model: LR
#                precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85      8522
#            1       0.05      0.80      0.10       158
#
#     accuracy                           0.74      8680
#    macro avg       0.52      0.77      0.47      8680
# weighted avg       0.98      0.74      0.83      8680
#
#
#
#  Accuracy of the "LR" model =  74.08 %
#
# normalized confusion matrix of the "LR" model
# [[0.73961511 0.26038489]
#  [0.19620253 0.80379747]]
# ...
#  Model: DT
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8522
#            1       0.07      0.08      0.07       158
#
#     accuracy                           0.96      8680
#    macro avg       0.53      0.53      0.53      8680
# weighted avg       0.97      0.96      0.97      8680
#
#
#
#  Accuracy of the "DT" model =  96.41 %
#
# normalized confusion matrix of the "DT" model
# [[0.980521   0.019479  ]
# ...

# %%
df_scores_ros_wo_none #without smoking_status column
# Out:
#   Classifier     Score
# 0         RF  0.978687
# 1         DT  0.964055
# 2         LR  0.740783

# %% [markdown]
# ### Comments on results (random oversampling- without smoking_status)
# This method is working pretty well, the Random Forest Classifier (RF) has the highest accuracy (97.87%) of predicting stroke disease, then the Decision Tree (DT) with (96.41%). The Linear Regression Classifier (LR) has prediction accuracy of (74.08%) which is approximately the same when I used **class_weight = 'balanced'** in the previous section. In general, the prediction was slightly improved compared to the previous method (Sec. B)

# %%
df_scores_ros_w_none = accuracy_confusion(clsf_none, X_ros_train_w, y_ros_train_w, X_test_w, y_test_w) #with smoking_status column
# Out:
#  Model: LR
#                precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85      8522
#            1       0.06      0.82      0.10       158
#
#     accuracy                           0.74      8680
#    macro avg       0.53      0.78      0.48      8680
# weighted avg       0.98      0.74      0.84      8680
#
#
#
#  Accuracy of the "LR" model =  74.29 %
#
# normalized confusion matrix of the "LR" model
# [[0.74149261 0.25850739]
#  [0.1835443  0.8164557 ]]
# ...
#  Model: DT
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8522
#            1       0.04      0.04      0.04       158
#
#     accuracy                           0.96      8680
#    macro avg       0.51      0.51      0.51      8680
# weighted avg       0.97      0.96      0.96      8680
#
#
#
#  Accuracy of the "DT" model =  96.44 %
#
# normalized confusion matrix of the "DT" model
# [[0.98145975 0.01854025]
# ...

# %%
df_scores_ros_w_none  #with smoking_status column
# Out:
#   Classifier     Score
# 0         RF  0.980069
# 1         DT  0.964401
# 2         LR  0.742857

# %% [markdown]
# ### Comments on results (random oversampling- with smoking_status)
# This method is working pretty well, the Random Forest Classifier (RF) has the highest accuracy (98.00%) of predicting stroke disease, then the Decision Tree (DT) with (96.44%). The Linear Regression Classifier (LR) has prediction accuracy of (74.29%). There is no significant improvements comparing to the results obtained previously. **It is noticed that, when I used the smoking_status column** to train the model, the accuracies has not changed much comparing to the results when **smoking_status** was removed from the dataset. This means, the smoking status of a patient is not significant on classifying the stroke disease.

# %% [markdown]
# ### Feature importance
# Here, I will use the random forest classifier to get the features importance of the data:

# %%
rfc_model = RandomForestClassifier(random_state = 2019)
rfc_model.fit(X_ros_train_w, y_ros_train_w)
features_importance = pd.DataFrame(rfc_model.feature_importances_, index = X_train_w.columns, columns=['feature_importance']).sort_values(by ='feature_importance', ascending = False)
print(features_importance)
features_importance.plot(kind='bar')
# Out:
#                    feature_importance
# age                          0.411903
# avg_glucose_level            0.203902
# bmi                          0.188307
# work_type                    0.053253
# ever_married                 0.033273
# smoking_status               0.032790
# gender                       0.020378
# Residence_type               0.019619
# hypertension                 0.019499
# heart_disease                0.017076

# %% [markdown]
# It is clear that the most important features are 'age', 'avg_glucose_level' and 'bmi'.

# %% [markdown]
# ### - Conclusion
# Classification of stroke disease is an interesting problems of machine learning on health sector. Many researchers/data scientists around the world attempted to solve it and then there are many approaches to deal with that problem. In this approach, the train data was downloaded from Kaggle and a python code was created to read the text data. Then, the data was explored by using pandas profiling model. Before building a classification model, the data were split into two sets: training set consists of 80% of the whole sample and test set which has the rest of stroke data. The stroke data consists of 9 features ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi'], and one target ['stroke']. The main aim is to use the training data to train a model to fit the trained features with the trained labels, then the model will be used to predicted labels of given features from the test set. Then, the predicted labels will be compared to the real ones and the accuracy of the model will be calculated.The higher the accuracy means the best performance of the model. On modeling step, since I have no preferred approach to any model, I used 3 machine learning models to classify the data. To choose the best model among them, the accuracy of each model was calculated and the results were sorted according to the accuracy values. Meanwhile, the confusion matrix was calculated and shown to visualize the accuracy of the model. In general, the best model among others is the Random Forest Classifier (RF), its accuracy = 98% when I used **random oversampling method** and when the dataset contains **smoking_status** column but the best model that could be used to predict both classes is the Logestic Regression (LR) with accuracy = 74.29%. Then, I recommend to use LR in classifying the stroke data.
#
# Thank you for your time!
